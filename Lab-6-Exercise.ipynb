# %%
# Asks the user to enter their name
name = input("Please enter your first and last name: ")

# %%
# Ask the user for their favorite color
color = input("Tell me your favorite color: ")

match color:
    case "dark green":
        print("Interesting...")
    case _:
        print("Very nice color :D")
# Out:
# Tell me your favorite color:  pink
# Very nice color :D

# %%
print("Hi " + name + " Your " + color + " is a nice color!")
# Out:
# Hi annabelleYour pink is a nice color!
